# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Leitura Tabelas - Comércio e Produção

# %%
path_processa_mesa = '../Dados/tech-challenge/content/ProcessaMesa.csv'
path_comercio = '../Dados/tech-challenge/content/Comercio.csv'
path_producao = '../Dados/tech-challenge/content/Producao.csv'

df_processa_mesa = pd.read_csv(path_processa_mesa, sep=';')

df_comercio = pd.read_csv(path_comercio, sep=';', names=df_processa_mesa.columns)
df_producao = pd.read_csv(path_producao, sep=';',names=df_processa_mesa.columns)

display(df_comercio.head())
display(df_producao.head())
# Out:
#    id              control             cultivar      1970       1971  \
# 0   1        VINHO DE MESA        VINHO DE MESA  98327606  114399031
# 1   2             vm_Tinto                Tinto  83300735   98522869
# 2   3            vm_Rosado               Rosado    107681     542274
# 3   4            vm_Branco               Branco  14919190   15333888
# 4   5  VINHO  FINO DE MESA  VINHO  FINO DE MESA   4430629    4840369
#
#         1972       1973      1974       1975       1976  ...       2012  \
# 0  118377367  116617910  94173324  108031792  139238614  ...  206969571
# 1  101167932   98196747  77167303   91528090  116407222  ...  173964776
# 2    7770851    8425617   8891367    7261777   11748047  ...    1738134
# 3    9438584    9995546   8114654    9241925   11083345  ...   31266661
# 4    5602091    7202830   7571802    8848303   14095648  ...   22469950
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %% [markdown]
# # Filtro - Ultimos 15 anos

# %%
filtro_colunas = ['control', 'cultivar','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']

df_comercio = df_comercio[filtro_colunas]
df_producao = df_producao[filtro_colunas]

# %% [markdown]
# # Analise

# %% [markdown]
# ## Comercio

# %% [markdown]
# - Os dados de comercio levantam quantos litros de bebida foram vendidos, levando em consideração o territorio nacional do Brasil.
# - Principais tipos de levantamentos a serem feitos:
#     1. Definir quais os grupos de bebidas que devem ser utilizadas na análise
#     R: (VINHO DE MESA/VINHO FINO DE MESA/VINHO FRIZANTE/VINHO ORGÂNICO/VINHO ESPECIAL)
#     2. Vendas em litros do somatorio desses grupos no decorrer do anos - Descobrir a tendencia de venda desses produtos
#     3. Porcentagem da composição da venda total em litros dos vinhos em cima do total geral - Produto com mercado mais abrangente
#     4. Da porcentagem do maior grupo, criar gráfico do somatorio apenas dessa bebida do decorrer dos anos e colocar a linha dos tipos desse vinho
#     5. Realizar um somatorio apenas do vinho de mesa x o somatorio de todos os outros grupo de bebidas - Para mostrar a força da venda
#     6. Mostrar porcentagem de cada tipo para o total dos vinhos produzidos no periodo completo

# %% [markdown]
# ## Produção

# %% [markdown]
# - Os dados de produção levantam quantos litros de bebida foram produzidos, levando em consideração o territorio nacional do Brasil.
# - Principais tipos de levantamentos a serem feitos:
#     1. Definir quais os grupos de bebidas que devem ser utilizadas na análise
#     R: (VINHO DE MESA/VINHO FINO DE MESA)
#     2. Produção em litros do somatorio desses grupos no decorrer dos anos
#     3. Porcentagem da composição de cada grupo no somatorio no decorrer dos anos
#     4. Identificar a porcentagem de cada tipo no grupo em cima do somatorio dos anos
#     5. Comparativo do tipo mais produzido no grupo do vinho de mesa, com os outros subgrupos
#     6. Identificar se em algum tipo de derivado existe uma relação os os menos produzidos do vinho

# %% [markdown]
# ## Comercio x Produção

# %% [markdown]
# - Cruzamento das fontes de dados produção e comercio
#     1. Fazer um comparativo apenas da produção x comercio de todas as bebidas no decorrer do anos - Validar se a produção é maior do que o comercio ou vice e versa (Aqui existem mais de um gráfico para identificar o comparativo)
#     2. Comparar a produção e comercio de tudo que é identificado vinho
#     2. Analisar o mercado das outras bebidas pelo comercio e produção
