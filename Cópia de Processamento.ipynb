# %% [markdown]
# ### Tabelas de **Processamento**

# %%
import pandas as pd

# %%
# Tabelas a serem trabalhadas -> Processamento
filePath='/Users/felipeassaf/Downloads/filesMarcelo'
path_processa_americana = filePath+'/content/ProcessaAmericanas.csv'
path_processa_mesa = filePath+'/content/ProcessaMesa.csv'
path_processa_sem = filePath+'/content/ProcessaSemclass.csv'
path_processa_vinifiras = filePath+'/content/ProcessaViniferas.csv'

# %%
df_processa_americanas = pd.read_csv(filePath+'/content/ProcessaAmericanas.csv', sep=';')
df_processa_mesa       = pd.read_csv(filePath+'/content/ProcessaMesa.csv', sep=';')
df_processa_sem_class  = pd.read_csv(filePath+'/content/ProcessaSemclass.csv', sep=';')
df_processa_viniferas  = pd.read_csv(filePath+'/content/ProcessaViniferas.csv', sep=';')

# %%
df_processa_americana = pd.read_csv(path_processa_americana, sep=';')
df_processa_mesa = pd.read_csv(path_processa_mesa, sep=';')
df_processa_sem = pd.read_csv(path_processa_sem, sep=';')
df_processa_viniferas = pd.read_csv(path_processa_vinifiras, sep=';')

# %% [markdown]
# ### Desenvolvimento Tabelas de **Processamento**

# %%
df_processa_americana.head()
# Out:
#    id         control     cultivar       1970       1971       1972  \
# 0   1          TINTAS       TINTAS  284285642  193695427  187251954
# 1   2     ti_Bacarina     Bacarina      82899     106962      67464
# 2   3       ti_Bailey       Bailey          0          0          0
# 3   4        ti_Bordo        Bordo    7242197    7227090    6530686
# 4   5  ti_Bourdin (S)  Bourdin (S)          0          0          0
#
#         1973       1974       1975       1976  ...       2012       2013  \
# 0  161593877  295404693  282003228  222289729  ...  527332818  460738996
# 1      58690     138158     101454      57297  ...       3820       2990
# 2          0          0          0          0  ...     912286     756000
# 3    5584243   13341412   16023998   12725233  ...  127378006  102788361
# 4          0          0          0          0  ...          0          0
#
#         2014       2015       2016       2017       2018  2019       2020  \
# ...

# %%
df_processa_americana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 55 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        60 non-null     int64
#  1   control   60 non-null     object
#  2   cultivar  60 non-null     object
#  3   1970      60 non-null     int64
#  4   1971      60 non-null     int64
#  5   1972      60 non-null     int64
#  6   1973      60 non-null     int64
#  7   1974      60 non-null     int64
#  8   1975      60 non-null     int64
#  9   1976      60 non-null     int64
#  10  1977      60 non-null     int64
#  11  1978      60 non-null     int64
#  12  1979      60 non-null     int64
#  13  1980      60 non-null     int64
#  14  1981      60 non-null     int64
#  15  1982      60 non-null     int64
#  16  1983      60 non-null     int64
#  17  1984      60 non-null     int64
#  18  1985      60 non-null     int64
#  19  1986      60 non-null     int64
# ...

# %%
# Removendo valores de tintas e brancas
# Descobrindo o valore do index e deletando

# Opcao 1: Mostrar Uvas exceto: TINTAS e BRANCAS E ROSADAS
#df_processa_americana = df_processa_americana[df_processa_americana.cultivar != 'TINTAS']
#df_processa_americana = df_processa_americana[df_processa_americana.cultivar != 'BRANCAS E ROSADAS']

# Opcao 2: Mostrar Uvas que ^ < Iniciem com: TINTAS | < Ou BRANCAS E ROSADAS e $ < Finalizem 
df_processa_americana = df_processa_americana[df_processa_americana['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

#df_processa_americana.head
# Out:
# /var/folders/m3/_rmsk88d72sd4j4hrxmtzk640000gn/T/ipykernel_4655/2801494793.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_processa_americana = df_processa_americana[df_processa_americana['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

# %%
df_processa_mesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 55 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10 non-null     int64
#  1   control   10 non-null     object
#  2   cultivar  10 non-null     object
#  3   1970      10 non-null     int64
#  4   1971      10 non-null     int64
#  5   1972      10 non-null     int64
#  6   1973      10 non-null     int64
#  7   1974      10 non-null     int64
#  8   1975      10 non-null     int64
#  9   1976      10 non-null     int64
#  10  1977      10 non-null     int64
#  11  1978      10 non-null     int64
#  12  1979      10 non-null     int64
#  13  1980      10 non-null     int64
#  14  1981      10 non-null     int64
#  15  1982      10 non-null     int64
#  16  1983      10 non-null     int64
#  17  1984      10 non-null     int64
#  18  1985      10 non-null     int64
#  19  1986      10 non-null     int64
# ...

# %%
df_processa_viniferas.tail()
# Out:
#       id        control    cultivar     1970     1971    1972    1973    1974  \
# 129  130     br_Verdiso     Verdiso     7950      770       0       0       0
# 130  131  br_Vermentino  Vermentino    20461     6097    8945    6153    8954
# 131  132   br_Vernaccia   Vernaccia   122467   190297  111691   65995  114553
# 132  133    br_Viognier    Viognier        0        0       0       0       0
# 133  134   br_Outras(3)   Outras(3)  2126291  1148313  648335  334680  200652
#
#        1975     1976  ...    2012    2013    2014    2015   2016    2017  \
# 129       0        0  ...       0       0       0       0      0       0
# 130    7070     6478  ...    4844    3220    1890     790      0       0
# 131  135975   142787  ...    3780    7970    4150    4760      0    5100
# 132       0        0  ...  200288  247081  149333  285217  95231  365103
# 133  270015  2089793  ...       0       0       0       0      0       0
#
#        2018  2019    2020   2021
# ...

# %%
# Removendo valores de tintas e brancas
# Descobrindo o valore do index e deletando

# Opcao 1: Mostrar Uvas exceto: TINTAS e BRANCAS E ROSADAS
#df_processa_mesa = df_processa_mesa[df_processa_mesa.cultivar != 'TINTAS']
#df_processa_mesa = df_processa_mesa[df_processa_mesa.cultivar != 'BRANCAS E ROSADAS']

# Opcao 2: Mostrar Uvas que ^ < Iniciem com: TINTAS | < Ou BRANCAS E ROSADAS e $ < Finalizem 
df_processa_mesa = df_processa_mesa[df_processa_mesa['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

#df_processa_americana.head
# Out:
# /var/folders/m3/_rmsk88d72sd4j4hrxmtzk640000gn/T/ipykernel_4655/22998358.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_processa_mesa = df_processa_mesa[df_processa_mesa['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

# %%
# Não precisa remover as linhas de  tipagem
df_processa_sem
# Out:
#    id control           cultivar     1970    1971    1972    1973   1974  \
# 0   1      sc  Sem classificação  3675463  665425  197232  491357  57307
#
#      1975   1976  ...  2012  2013  2014  2015  2016  2017  2018  2019    2020  \
# 0  540146  24440  ...     0     0     0     0     0     0     0    nd  166947
#
#    2021
# 0     0
#
# [1 rows x 55 columns]

# %%
# Removendo valores de tintas e brancas
# Descobrindo o valore do index e deletando

# Opcao 1: Mostrar Uvas exceto: TINTAS e BRANCAS E ROSADAS
#df_processa_viniferas = df_processa_viniferas[df_processa_viniferas.cultivar != 'TINTAS']
#df_processa_viniferas = df_processa_viniferas[df_processa_viniferas.cultivar != 'BRANCAS E ROSADAS']

# Opcao 2: Mostrar Uvas que ^ < Iniciem com: TINTAS | < Ou BRANCAS E ROSADAS e $ < Finalizem 
df_processa_viniferas = df_processa_viniferas[df_processa_viniferas['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

#df_processa_americana.head
# Out:
# /var/folders/m3/_rmsk88d72sd4j4hrxmtzk640000gn/T/ipykernel_4655/1569338534.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_processa_viniferas = df_processa_viniferas[df_processa_viniferas['cultivar'].str.contains('^(TINTAS|BRANCAS E ROSADAS)$', regex=True)]

# %%
df_processa_viniferas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 69
# Data columns (total 55 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        2 non-null      int64
#  1   control   2 non-null      object
#  2   cultivar  2 non-null      object
#  3   1970      2 non-null      int64
#  4   1971      2 non-null      int64
#  5   1972      2 non-null      int64
#  6   1973      2 non-null      int64
#  7   1974      2 non-null      int64
#  8   1975      2 non-null      int64
#  9   1976      2 non-null      int64
#  10  1977      2 non-null      int64
#  11  1978      2 non-null      int64
#  12  1979      2 non-null      int64
#  13  1980      2 non-null      int64
#  14  1981      2 non-null      int64
#  15  1982      2 non-null      int64
#  16  1983      2 non-null      int64
#  17  1984      2 non-null      int64
#  18  1985      2 non-null      int64
#  19  1986      2 non-null      int64
# ...

# %%
# Merge das processa
df_processa = pd.concat([df_processa_americana,df_processa_mesa,df_processa_viniferas,df_processa_sem])

# %%
df_processa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 0
# Data columns (total 55 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        6 non-null      int64
#  1   control   6 non-null      object
#  2   cultivar  6 non-null      object
#  3   1970      6 non-null      int64
#  4   1971      6 non-null      int64
#  5   1972      6 non-null      int64
#  6   1973      6 non-null      int64
#  7   1974      6 non-null      int64
#  8   1975      6 non-null      int64
#  9   1976      6 non-null      int64
#  10  1977      6 non-null      int64
#  11  1978      6 non-null      int64
#  12  1979      6 non-null      int64
#  13  1980      6 non-null      int64
#  14  1981      6 non-null      int64
#  15  1982      6 non-null      int64
#  16  1983      6 non-null      int64
#  17  1984      6 non-null      int64
#  18  1985      6 non-null      int64
#  19  1986      6 non-null      int64
# ...

# %%
df_processa_filtrada =df_processa[['control', 'cultivar','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']]

# %%
df_periodos = df_processa.iloc[:,40:55]
df_tipos = df_processa.iloc[:, 1:3]
df_tipos
# Out:
#             control           cultivar
# 0            TINTAS             TINTAS
# 35  BRANCASEROSADAS  BRANCAS E ROSADAS
# 0            TINTAS             TINTAS
# 0            TINTAS             TINTAS
# 69  BRANCASEROSADAS  BRANCAS E ROSADAS
# 0                sc  Sem classificação

# %%
df_periodos
# Out:
#          2007       2008       2009       2010       2011       2012  \
# 0   430628346  466504230  391196306  409514092  532937101  527332818
# 35   67888444   83917393   71110317   71589617   94137074   93549583
# 0       66970     101101      84397      31771      89305     145132
# 0    43653087   48852574   39148123   23633831   44473588   39303313
# 69   28254191   34602464   32556903   22104122   37931015   36519724
# 0           0          0          0          0          0          0
#
#          2013       2014       2015       2016       2017       2018 2019  \
# 0   460738996  471555903  537592720  235356261  600605876  519506589   nd
# 35   77174438   68847961   95439129   32747787   74888637   79044471   nd
# 0       75362      65850     108797      51310      85510      62567   nd
# 0    36855419   29810706   29935627   13370866   32850915   26868514   nd
# 69   36958341   35769155   40130577   18769366   44058213   38722156   nd
# ...

# %%
# Novo jeito de juntar as tabelas pela colunas
df_concat = pd.concat([df_tipos, df_periodos], axis=1)
df_concat
# Out:
#             control           cultivar       2007       2008       2009  \
# 0            TINTAS             TINTAS  430628346  466504230  391196306
# 35  BRANCASEROSADAS  BRANCAS E ROSADAS   67888444   83917393   71110317
# 0            TINTAS             TINTAS      66970     101101      84397
# 0            TINTAS             TINTAS   43653087   48852574   39148123
# 69  BRANCASEROSADAS  BRANCAS E ROSADAS   28254191   34602464   32556903
# 0                sc  Sem classificação          0          0          0
#
#          2010       2011       2012       2013       2014       2015  \
# 0   409514092  532937101  527332818  460738996  471555903  537592720
# 35   71589617   94137074   93549583   77174438   68847961   95439129
# 0       31771      89305     145132      75362      65850     108797
# 0    23633831   44473588   39303313   36855419   29810706   29935627
# 69   22104122   37931015   36519724   36958341   35769155   40130577
# ...

# %%
df_concat = df_concat.set_index('cultivar')
df_concat.head()
# Out:
#                            control       2007       2008       2009  \
# cultivar
# TINTAS                      TINTAS  430628346  466504230  391196306
# BRANCAS E ROSADAS  BRANCASEROSADAS   67888444   83917393   71110317
# TINTAS                      TINTAS      66970     101101      84397
# TINTAS                      TINTAS   43653087   48852574   39148123
# BRANCAS E ROSADAS  BRANCASEROSADAS   28254191   34602464   32556903
#
#                         2010       2011       2012       2013       2014  \
# cultivar
# TINTAS             409514092  532937101  527332818  460738996  471555903
# BRANCAS E ROSADAS   71589617   94137074   93549583   77174438   68847961
# TINTAS                 31771      89305     145132      75362      65850
# TINTAS              23633831   44473588   39303313   36855419   29810706
# BRANCAS E ROSADAS   22104122   37931015   36519724   36958341   35769155
#
#                         2015       2016       2017       2018 2019       2020  \
# cultivar
# ...

# %%
df_processa_filtrada.head()
# Out:
#             control           cultivar       2007       2008       2009  \
# 0            TINTAS             TINTAS  430628346  466504230  391196306
# 35  BRANCASEROSADAS  BRANCAS E ROSADAS   67888444   83917393   71110317
# 0            TINTAS             TINTAS      66970     101101      84397
# 0            TINTAS             TINTAS   43653087   48852574   39148123
# 69  BRANCASEROSADAS  BRANCAS E ROSADAS   28254191   34602464   32556903
#
#          2010       2011       2012       2013       2014       2015  \
# 0   409514092  532937101  527332818  460738996  471555903  537592720
# 35   71589617   94137074   93549583   77174438   68847961   95439129
# 0       31771      89305     145132      75362      65850     108797
# 0    23633831   44473588   39303313   36855419   29810706   29935627
# 69   22104122   37931015   36519724   36958341   35769155   40130577
#
#          2016       2017       2018 2019       2020       2021
# ...

# %%
import matplotlib.ticker as ticker

#axis = df_concat.transpose().iloc[1:,:].head().plot( figsize= (12,6))
#axis = df_concat.iloc[1:,:].head().plot( figsize= (12,6), kind='bar')   
df_concat.head()

axis = df_concat.head().plot( figsize= (12,6), kind='bar')   
axis.xaxis.set_data_interval
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.2f}"))

# %%
df_concat['2021']
# Out:
# cultivar
# TINTAS               394224543
# BRANCAS E ROSADAS    175576873
# TINTAS                   21732
# TINTAS                93296587
# BRANCAS E ROSADAS     71266239
# Sem classificação            0
# Name: 2021, dtype: int64

# %%
df_concat.drop(columns=['control'])
df_concat.T.head()
# Out:
# cultivar     TINTAS BRANCAS E ROSADAS  TINTAS    TINTAS BRANCAS E ROSADAS  \
# control      TINTAS   BRANCASEROSADAS  TINTAS    TINTAS   BRANCASEROSADAS
# 2007      430628346          67888444   66970  43653087          28254191
# 2008      466504230          83917393  101101  48852574          34602464
# 2009      391196306          71110317   84397  39148123          32556903
# 2010      409514092          71589617   31771  23633831          22104122
#
# cultivar Sem classificação
# control                 sc
# 2007                     0
# 2008                     0
# 2009                     0
# 2010                     0

# %%
df_concat.T.head()
df_concat.T.plot( figsize = (12,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1260], line 2
#       1 df_concat.T.head()
# ----> 2 df_concat.T.plot( figsize = (12,6))
#
# File /usr/local/lib/python3.9/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:446, in MPLPlot.generate(self)
# ...
